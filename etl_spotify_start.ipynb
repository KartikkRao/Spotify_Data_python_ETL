# %%
pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.24.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.0.7-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: requests>=2.25.0 in d:\anaconda\lib\site-packages (from spotipy) (2.32.2)
# Requirement already satisfied: urllib3>=1.26.0 in d:\anaconda\lib\site-packages (from spotipy) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests>=2.25.0->spotipy) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests>=2.25.0->spotipy) (2024.7.4)
# Downloading spotipy-2.24.0-py3-none-any.whl (30 kB)
# Downloading redis-5.0.7-py3-none-any.whl (252 kB)
#    ---------------------------------------- 0.0/252.1 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/252.1 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------  245.8/252.1 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 252.1/252.1 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.0.7 spotipy-2.24.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="Your_id" , client_secret="your_secret")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

# %%
 playlist_link.split('/')
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '37i9dQZEVXbNG2KDcFcKOF']

# %%
playlist_uri = playlist_link.split('/')[-1]

# %%
sp.playlist_tracks(playlist_uri)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-07-26T08:56:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/02687a01e9ec00f4e947f39e910c7e0c6fa83e10?cid=e11a83420c104da3bb4a55389148c22a',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/15XcLhiVMlSOipUddTNDnr',
#      'id': '15XcLhiVMlSOipUddTNDnr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f02c451189a709b9a952aaec',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f02c451189a709b9a952aaec',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f02c451189a709b9a952aaec',
#        'width': 64}],
#      'name': 'MUSE',
#      'release_date': '2024-07-19',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:15XcLhiVMlSOipUddTNDnr',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1oSPZhvZMIrWW5I41kPkkY'},
#        'href': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY',
#        'id': '1oSPZhvZMIrWW5I41kPkkY',
#        'name': 'Jimin',
#        'type': 'artist',
#        'uri': 'spotify:artist:1oSPZhvZMIrWW5I41kPkkY'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#      'total_tracks': 7},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1oSPZhvZMIrWW5I41kPkkY'},
#       'href': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY',
#       'id': '1oSPZhvZMIrWW5I41kPkkY',
#       'name': 'Jimin',
#       'type': 'artist',
#       'uri': 'spotify:artist:1oSPZhvZMIrWW5I41kPkkY'}],
#     'disc_number': 1,
#     'track_number': 6,
#     'duration_ms': 170887,
#     'external_ids': {'isrc': 'USA2P2431062'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7tI8dRuH2Yc6RuoTjxo4dU'},
#     'href': 'https://api.spotify.com/v1/tracks/7tI8dRuH2Yc6RuoTjxo4dU',
#     'id': '7tI8dRuH2Yc6RuoTjxo4dU',
#     'name': 'Who',
#     'popularity': 92,
#     'uri': 'spotify:track:7tI8dRuH2Yc6RuoTjxo4dU',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-07-26T08:56:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/7aJuG4TFXa2hmE4z1yxc3n',
#      'id': '7aJuG4TFXa2hmE4z1yxc3n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27371d62ea7ea8a5be92d3c1f62',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0271d62ea7ea8a5be92d3c1f62',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485171d62ea7ea8a5be92d3c1f62',
#        'width': 64}],
#      'name': 'HIT ME HARD AND SOFT',
#      'release_date': '2024-05-17',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:7aJuG4TFXa2hmE4z1yxc3n',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#      'total_tracks': 10},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'disc_number': 1,
#     'track_number': 4,
#     'duration_ms': 210373,
#     'external_ids': {'isrc': 'USUM72401994'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB'},
#     'href': 'https://api.spotify.com/v1/tracks/6dOtVTDdiauQNBQEDOtlAB',
#     'id': '6dOtVTDdiauQNBQEDOtlAB',
#     'name': 'BIRDS OF A FEATHER',
#     'popularity': 99,
#     'uri': 'spotify:track:6dOtVTDdiauQNBQEDOtlAB',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-07-26T08:56:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/5quMTd5zeI9yW5UDua8wS4',
#      'id': '5quMTd5zeI9yW5UDua8wS4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273659cd4673230913b3918e0d5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02659cd4673230913b3918e0d5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851659cd4673230913b3918e0d5',
#        'width': 64}],
#      'name': 'Espresso',
#      'release_date': '2024-04-12',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5quMTd5zeI9yW5UDua8wS4',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#        'href': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B',
#        'id': '74KM79TiuVKeVCqs8QtB0B',
#        'name': 'Sabrina Carpenter',
#        'type': 'artist',
#        'uri': 'spotify:artist:74KM79TiuVKeVCqs8QtB0B'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#       'href': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B',
#       'id': '74KM79TiuVKeVCqs8QtB0B',
#       'name': 'Sabrina Carpenter',
#       'type': 'artist',
#       'uri': 'spotify:artist:74KM79TiuVKeVCqs8QtB0B'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 175459,
#     'external_ids': {'isrc': 'USUM72403305'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2qSkIjg1o9h3YT9RAgYN75'},
#     'href': 'https://api.spotify.com/v1/tracks/2qSkIjg1o9h3YT9RAgYN75',
#     'id': '2qSkIjg1o9h3YT9RAgYN75',
#     'name': 'Espresso',
#     'popularity': 99,
#     'uri': 'spotify:track:2qSkIjg1o9h3YT9RAgYN75',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-07-26T08:56:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/5bBaoign62r1i7OV8w7mi9',
#      'id': '5bBaoign62r1i7OV8w7mi9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273de84adf0e48248ea2d769c3e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02de84adf0e48248ea2d769c3e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851de84adf0e48248ea2d769c3e',
#        'width': 64}],
#      'name': 'Please Please Please',
#      'release_date': '2024-06-06',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5bBaoign62r1i7OV8w7mi9',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#        'href': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B',
#        'id': '74KM79TiuVKeVCqs8QtB0B',
#        'name': 'Sabrina Carpenter',
#        'type': 'artist',
#        'uri': 'spotify:artist:74KM79TiuVKeVCqs8QtB0B'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5bBaoign62r1i7OV8w7mi9'},
#      'total_tracks': 2},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#       'href': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B',
#       'id': '74KM79TiuVKeVCqs8QtB0B',
#       'name': 'Sabrina Carpenter',
#       'type': 'artist',
#       'uri': 'spotify:artist:74KM79TiuVKeVCqs8QtB0B'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 186365,
#     'external_ids': {'isrc': 'USUM72404101'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5N3hjp1WNayUPZrA8kJmJP'},
#     'href': 'https://api.spotify.com/v1/tracks/5N3hjp1WNayUPZrA8kJmJP',
#     'id': '5N3hjp1WNayUPZrA8kJmJP',
#     'name': 'Please Please Please',
#     'popularity': 98,
#     'uri': 'spotify:track:5N3hjp1WNayUPZrA8kJmJP',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-07-26T08:56:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/5JjnoGJyOxfSZUZtk2rRwZ',
#      'id': '5JjnoGJyOxfSZUZtk2rRwZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731ea0c62b2339cbf493a999ad',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021ea0c62b2339cbf493a999ad',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511ea0c62b2339cbf493a999ad',
#        'width': 64}],
#      'name': 'Not Like Us',
#      'release_date': '2024-05-04',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5JjnoGJyOxfSZUZtk2rRwZ',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#        'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#        'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#        'name': 'Kendrick Lamar',
#        'type': 'artist',
#        'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#       'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#       'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#       'name': 'Kendrick Lamar',
#       'type': 'artist',
#       'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 274192,
#     'external_ids': {'isrc': 'USUG12400910'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6AI3ezQ4o3HUoP6Dhudph3'},
#     'href': 'https://api.spotify.com/v1/tracks/6AI3ezQ4o3HUoP6Dhudph3',
#     'id': '6AI3ezQ4o3HUoP6Dhudph3',
#     'name': 'Not Like Us',
#     'popularity': 97,
#     'uri': 'spotify:track:6AI3ezQ4o3HUoP6Dhudph3',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-07-26T08:56:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/12ae7f061a9da14a7c1e6a3e21de68365697efe8?cid=e11a83420c104da3bb4a55389148c22a',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/5tSQtQGkrCJx3hoQxmLgfM',
#      'id': '5tSQtQGkrCJx3hoQxmLgfM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c4583f3ad76630879a75450a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c4583f3ad76630879a75450a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c4583f3ad76630879a75450a',
#        'width': 64}],
#      'name': 'Gata Only',
#      'release_date': '2024-02-02',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5tSQtQGkrCJx3hoQxmLgfM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CvTknweLr9feJtRGrpDBy'},
#        'href': 'https://api.spotify.com/v1/artists/7CvTknweLr9feJtRGrpDBy',
#        'id': '7CvTknweLr9feJtRGrpDBy',
#        'name': 'FloyyMenor',
#        'type': 'artist',
#        'uri': 'spotify:artist:7CvTknweLr9feJtRGrpDBy'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Yj5Xey7kTwvZla8sqdsdE'},
#        'href': 'https://api.spotify.com/v1/artists/1Yj5Xey7kTwvZla8sqdsdE',
#        'id': '1Yj5Xey7kTwvZla8sqdsdE',
#        'name': 'Cris Mj',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Yj5Xey7kTwvZla8sqdsdE'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5tSQtQGkrCJx3hoQxmLgfM'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CvTknweLr9feJtRGrpDBy'},
#       'href': 'https://api.spotify.com/v1/artists/7CvTknweLr9feJtRGrpDBy',
#       'id': '7CvTknweLr9feJtRGrpDBy',
#       'name': 'FloyyMenor',
#       'type': 'artist',
#       'uri': 'spotify:artist:7CvTknweLr9feJtRGrpDBy'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Yj5Xey7kTwvZla8sqdsdE'},
#       'href': 'https://api.spotify.com/v1/artists/1Yj5Xey7kTwvZla8sqdsdE',
#       'id': '1Yj5Xey7kTwvZla8sqdsdE',
#       'name': 'Cris Mj',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Yj5Xey7kTwvZla8sqdsdE'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 222000,
#     'external_ids': {'isrc': 'QZL382406049'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6XjDF6nds4DE2BBbagZol6'},
#     'href': 'https://api.spotify.com/v1/tracks/6XjDF6nds4DE2BBbagZol6',
#     'id': '6XjDF6nds4DE2BBbagZol6',
#     'name': 'Gata Only',
#     'popularity': 96,
#     'uri': 'spotify:track:6XjDF6nds4DE2BBbagZol6',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-07-26T08:56:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/1WAjjRMfZjEXtB0lQrAw6Q',
#      'id': '1WAjjRMfZjEXtB0lQrAw6Q',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27391b4bc7c88d91a42e0f3a8b7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0291b4bc7c88d91a42e0f3a8b7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485191b4bc7c88d91a42e0f3a8b7',
#        'width': 64}],
#      'name': 'Good Luck, Babe!',
#      'release_date': '2024-04-05',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:1WAjjRMfZjEXtB0lQrAw6Q',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GlBOeep6PqTfFi59PTUUN'},
#        'href': 'https://api.spotify.com/v1/artists/7GlBOeep6PqTfFi59PTUUN',
#        'id': '7GlBOeep6PqTfFi59PTUUN',
#        'name': 'Chappell Roan',
#        'type': 'artist',
#        'uri': 'spotify:artist:7GlBOeep6PqTfFi59PTUUN'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1WAjjRMfZjEXtB0lQrAw6Q'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GlBOeep6PqTfFi59PTUUN'},
#       'href': 'https://api.spotify.com/v1/artists/7GlBOeep6PqTfFi59PTUUN',
#       'id': '7GlBOeep6PqTfFi59PTUUN',
#       'name': 'Chappell Roan',
#       'type': 'artist',
#       'uri': 'spotify:artist:7GlBOeep6PqTfFi59PTUUN'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 218423,
#     'external_ids': {'isrc': 'USUG12401967'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0WbMK4wrZ1wFSty9F7FCgu'},
#     'href': 'https://api.spotify.com/v1/tracks/0WbMK4wrZ1wFSty9F7FCgu',
#     'id': '0WbMK4wrZ1wFSty9F7FCgu',
#     'name': 'Good Luck, Babe!',
#     'popularity': 96,
#     'uri': 'spotify:track:0WbMK4wrZ1wFSty9F7FCgu',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-07-26T08:56:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
# ...
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02741fd4807f442af3f7359316',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851741fd4807f442af3f7359316',
#        'width': 64}],
#      'name': 'GOLDEN',
#      'release_date': '2023-11-03',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5pSk3c3wVwnb2arb6ohCPU',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#        'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#        'id': '6HaGTQPmzraVmaVxvz6EUc',
#        'name': 'Jung Kook',
#        'type': 'artist',
#        'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5pSk3c3wVwnb2arb6ohCPU'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#       'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#       'id': '6HaGTQPmzraVmaVxvz6EUc',
#       'name': 'Jung Kook',
#       'type': 'artist',
#       'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3MdXrJWsbVzdn6fe5JYkSQ'},
#       'href': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ',
#       'id': '3MdXrJWsbVzdn6fe5JYkSQ',
#       'name': 'Latto',
#       'type': 'artist',
#       'uri': 'spotify:artist:3MdXrJWsbVzdn6fe5JYkSQ'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 183550,
#     'external_ids': {'isrc': 'USA2P2330093'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2HRgqmZQC0MC7GeNuDIXHN'},
#     'href': 'https://api.spotify.com/v1/tracks/2HRgqmZQC0MC7GeNuDIXHN',
#     'id': '2HRgqmZQC0MC7GeNuDIXHN',
#     'name': 'Seven (feat. Latto) (Explicit Ver.)',
#     'popularity': 86,
#     'uri': 'spotify:track:2HRgqmZQC0MC7GeNuDIXHN',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-07-26T08:56:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/50ZenUP4O2Q5eCy2NRNvuz',
#      'id': '50ZenUP4O2Q5eCy2NRNvuz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736ee35072df1af802cca09918',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026ee35072df1af802cca09918',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516ee35072df1af802cca09918',
#        'width': 64}],
#      'name': 'Stick Season',
#      'release_date': '2022-10-14',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:50ZenUP4O2Q5eCy2NRNvuz',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RQXRUsr4IW1f3mKyKsy4B'},
#        'href': 'https://api.spotify.com/v1/artists/2RQXRUsr4IW1f3mKyKsy4B',
#        'id': '2RQXRUsr4IW1f3mKyKsy4B',
#        'name': 'Noah Kahan',
#        'type': 'artist',
#        'uri': 'spotify:artist:2RQXRUsr4IW1f3mKyKsy4B'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/50ZenUP4O2Q5eCy2NRNvuz'},
#      'total_tracks': 14},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RQXRUsr4IW1f3mKyKsy4B'},
#       'href': 'https://api.spotify.com/v1/artists/2RQXRUsr4IW1f3mKyKsy4B',
#       'id': '2RQXRUsr4IW1f3mKyKsy4B',
#       'name': 'Noah Kahan',
#       'type': 'artist',
#       'uri': 'spotify:artist:2RQXRUsr4IW1f3mKyKsy4B'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 182346,
#     'external_ids': {'isrc': 'USUM72212470'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0mflMxspEfB0VbI1kyLiAv'},
#     'href': 'https://api.spotify.com/v1/tracks/0mflMxspEfB0VbI1kyLiAv',
#     'id': '0mflMxspEfB0VbI1kyLiAv',
#     'name': 'Stick Season',
#     'popularity': 90,
#     'uri': 'spotify:track:0mflMxspEfB0VbI1kyLiAv',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-07-26T08:56:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/58XIBpQOAw7E2qCL1jxWCd',
#      'id': '58XIBpQOAw7E2qCL1jxWCd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e1a7ec3a606b52b7328d3e78',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e1a7ec3a606b52b7328d3e78',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e1a7ec3a606b52b7328d3e78',
#        'width': 64}],
#      'name': 'Tough',
#      'release_date': '2024-07-03',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:58XIBpQOAw7E2qCL1jxWCd',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0VRj0yCOv2FXJNP47XQnx5'},
#        'href': 'https://api.spotify.com/v1/artists/0VRj0yCOv2FXJNP47XQnx5',
#        'id': '0VRj0yCOv2FXJNP47XQnx5',
#        'name': 'Quavo',
#        'type': 'artist',
#        'uri': 'spotify:artist:0VRj0yCOv2FXJNP47XQnx5'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/00FQb4jTyendYWaN8pK0wa'},
#        'href': 'https://api.spotify.com/v1/artists/00FQb4jTyendYWaN8pK0wa',
#        'id': '00FQb4jTyendYWaN8pK0wa',
#        'name': 'Lana Del Rey',
#        'type': 'artist',
#        'uri': 'spotify:artist:00FQb4jTyendYWaN8pK0wa'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/58XIBpQOAw7E2qCL1jxWCd'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0VRj0yCOv2FXJNP47XQnx5'},
#       'href': 'https://api.spotify.com/v1/artists/0VRj0yCOv2FXJNP47XQnx5',
#       'id': '0VRj0yCOv2FXJNP47XQnx5',
#       'name': 'Quavo',
#       'type': 'artist',
#       'uri': 'spotify:artist:0VRj0yCOv2FXJNP47XQnx5'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/00FQb4jTyendYWaN8pK0wa'},
#       'href': 'https://api.spotify.com/v1/artists/00FQb4jTyendYWaN8pK0wa',
#       'id': '00FQb4jTyendYWaN8pK0wa',
#       'name': 'Lana Del Rey',
#       'type': 'artist',
#       'uri': 'spotify:artist:00FQb4jTyendYWaN8pK0wa'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 188828,
#     'external_ids': {'isrc': 'USUG12400072'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/22DH8NChecsgPxDjA4pqer'},
#     'href': 'https://api.spotify.com/v1/tracks/22DH8NChecsgPxDjA4pqer',
#     'id': '22DH8NChecsgPxDjA4pqer',
#     'name': 'Tough',
#     'popularity': 88,
#     'uri': 'spotify:track:22DH8NChecsgPxDjA4pqer',
#     'is_local': False},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 50}

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
data['items'][1]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'explicit': False,
#  'type': 'track',
#  'episode': False,
#  'track': True,
#  'album': {'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'type': 'album',
#   'album_type': 'album',
#   'href': 'https://api.spotify.com/v1/albums/7aJuG4TFXa2hmE4z1yxc3n',
#   'id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27371d62ea7ea8a5be92d3c1f62',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0271d62ea7ea8a5be92d3c1f62',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485171d62ea7ea8a5be92d3c1f62',
#     'width': 64}],
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'release_date_precision': 'day',
#   'uri': 'spotify:album:7aJuG4TFXa2hmE4z1yxc3n',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#   'total_tracks': 10},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#    'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#    'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#    'name': 'Billie Eilish',
#    'type': 'artist',
#    'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#  'disc_number': 1,
#  'track_number': 4,
#  'duration_ms': 210373,
#  'external_ids': {'isrc': 'USUM72401994'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB'},
#  'href': 'https://api.spotify.com/v1/tracks/6dOtVTDdiauQNBQEDOtlAB',
#  'id': '6dOtVTDdiauQNBQEDOtlAB',
#  'name': 'BIRDS OF A FEATHER',
#  'popularity': 99,
#  'uri': 'spotify:track:6dOtVTDdiauQNBQEDOtlAB',
#  'is_local': False}

# %%
data['items'][1]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'type': 'album',
#  'album_type': 'album',
#  'href': 'https://api.spotify.com/v1/albums/7aJuG4TFXa2hmE4z1yxc3n',
#  'id': '7aJuG4TFXa2hmE4z1yxc3n',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b27371d62ea7ea8a5be92d3c1f62',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e0271d62ea7ea8a5be92d3c1f62',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d0000485171d62ea7ea8a5be92d3c1f62',
#    'width': 64}],
#  'name': 'HIT ME HARD AND SOFT',
#  'release_date': '2024-05-17',
#  'release_date_precision': 'day',
#  'uri': 'spotify:album:7aJuG4TFXa2hmE4z1yxc3n',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#    'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#    'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#    'name': 'Billie Eilish',
#    'type': 'artist',
#    'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  'total_tracks': 10}

# %%
data['items'][1]['track']['album']['id']
# Out:
# '7aJuG4TFXa2hmE4z1yxc3n'

# %%
data['items'][1]['track']['album']['name'] #album name
# Out:
# 'HIT ME HARD AND SOFT'

# %%
data['items'][1]['track']['album']['release_date']
# Out:
# '2024-05-17'

# %%
data['items'][1]['track']['album']['external_urls']['spotify'] #album link
# Out:
# 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'

# %%
data['items'][1]['track']['album']['total_tracks']
# Out:
# 10

# %%
#data['items'][1]['track']['album']['artists'][0]['name'] #artist name
name = []
for item in data['items'][5]['track']['album']['artists']:
    name.append(item['name'])
print(name)
# Out:
# ['FloyyMenor', 'Cris Mj']

# %%
data['items'][1]['track']['name'] #song name
# Out:
# 'BIRDS OF A FEATHER'

# %%
data['items'][1]['track']['popularity']
# Out:
# 99

# %%
data['items'][1]['track']['external_urls']['spotify'] #song link
# Out:
# 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB'

# %%
album_list=[]
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    song_name = row['track']['name']
    song_popularity_rating = row['track']['popularity']
    name = []
    for item in row['track']['album']['artists']:
        name.append(item['name'])
    artist_name = name
    album_total_tracks = row['track']['album']['total_tracks']
    album_link = row['track']['album']['external_urls']['spotify']
    song_link = row['track']['external_urls']['spotify']
    
    album = {'album_id': album_id , 'album_name': album_name , 'album_release_date': album_release_date , 'song_name': song_name ,
            'song_popularity_rating': song_popularity_rating ,'artist_name': artist_name , 'album_total_tracks': album_total_tracks ,
            'album_link': album_link , 'song_link': song_link} 
    album_list.append(album)

# %%
df = pd.DataFrame.from_dict(album_list)

# %%
df
# Out:
#                   album_id                                         album_name  \
# 0   15XcLhiVMlSOipUddTNDnr                                               MUSE
# 1   7aJuG4TFXa2hmE4z1yxc3n                               HIT ME HARD AND SOFT
# 2   5quMTd5zeI9yW5UDua8wS4                                           Espresso
# 3   5bBaoign62r1i7OV8w7mi9                               Please Please Please
# 4   5JjnoGJyOxfSZUZtk2rRwZ                                        Not Like Us
# 5   5tSQtQGkrCJx3hoQxmLgfM                                          Gata Only
# 6   1WAjjRMfZjEXtB0lQrAw6Q                                   Good Luck, Babe!
# 7   5ylbxH7EqpsmHZCRuiYewS                       Si Antes Te Hubiera Conocido
# 8   168CdR21lfn0TTyw1Pkdcm                           Fireworks & Rollerblades
# 9   0DLvFVIfwt3OHdK9kGeEM3             Where I've Been, Isn't Where I'm Going
# 10  2Z1gnUf3nbn6DtwZSUIH54                                MILLION DOLLAR BABY
# 11  2m0euKZUDcoyEXHIS5MFCq                Alibi (with Pabllo Vittar & Yseult)
# 12  3P4SQqMMgjqfqVxgLwtYRk                            Unreal Unearth: Unheard
# 13  1woYXxyyxTQJ0E0AhZE6mj                                    I Had Some Help
# 14  7nacKlk586eLRBSIsrk9DB         I've Tried Everything But Therapy (Part 1)
# 15  3kjHLu1pL7tdY88GFwEkl6            The Death of Slim Shady (Coup De Grâce)
# 16  3VNxRarx9HUI5w7DHv0TBj                                         Stargazing
# 17  4JDXBZdRPId4devseaAOKH                                             DECIDE
# 18  5r36AJ6VOJtp00oxSkBZ5h                                      Harry's House
# 19  3EWJoKrG9XnCjvAPzkQZ88                                    EL ÚLTIMO BAILE
# 20  5nzSCZ7NhKvAysI0tmNOdD                                            yustyna
# 21  1NAmidJlEaVgA3MpcPFYGq                                              Lover
# 22  5EYKrEDnKhhcNxGedaRQeK                                   eternal sunshine
# 23  7tzVd1fwkxsorytCBjEJkU  The Idol Episode 4 (Music from the HBO Origina...
# 24  4sD1qg4jwTZR4mvR4Iflk5                                     Strange Trails
# 25  7aJuG4TFXa2hmE4z1yxc3n                               HIT ME HARD AND SOFT
# 26  40HsqPqeSR9Xe3IyAJWr6e                                  What Happens Now?
# 27  4M8ThNHbNjda2cPwL8XZHS                                               Move
# 28  3PlCMwyq6nuQYtoYproV1o                                    Belong Together
# 29  7wIIhHPyaxAHRvdNQQO2G9                                           Rockstar
# 30  1CEODgTmTwLyabvwd7HBty          Viva La Vida or Death and All His Friends
# 31  0lgs2Sa82lyX89nBUWyUy6                                     FERXXOCALIPSIS
# 32  1Mo4aZ8pdj6L1jx8zSwJnt                      THE TORTURED POETS DEPARTMENT
# 33  4xkM0BwLM9H2IUcbYzpcBI                                        I Love You.
# 34  78bpIziExqiI9qztvNFlQu                                                 AM
# 35  1uLAcaywb5673rQ2lJ1UG7                                                ATE
# 36  7aJuG4TFXa2hmE4z1yxc3n                               HIT ME HARD AND SOFT
# 37  5oCAS6VzHoESewtXUGMqbz                                             Mirame
# 38  3uzutRS5qX4ng5Skjh5S6W                                              Santa
# 39  4AzPr5SUpNF553eC1d3aRy                         BAND4BAND (feat. Lil Baby)
# 40  0FzWvaeMBfKBCqxHTLVlB8                                              MEGAN
# 41  0EiI8ylL0FmWWpgHVTsZjZ            The Rise and Fall of a Midwest Princess
# 42  168CdR21lfn0TTyw1Pkdcm                           Fireworks & Rollerblades
# 43  15XcLhiVMlSOipUddTNDnr                                               MUSE
# 44  0wCLHkBRKcndhMQQpeo8Ji                                 I Don't Wanna Wait
# 45  18NOKLkZETa4sWwLMIm0UZ                                             UTOPIA
# 46  1SiWjniEb94wSFZ5YjZDHr                    Did It First (with Central Cee)
# 47  5pSk3c3wVwnb2arb6ohCPU                                             GOLDEN
# 48  50ZenUP4O2Q5eCy2NRNvuz                                       Stick Season
# 49  58XIBpQOAw7E2qCL1jxWCd                                              Tough
#
#    album_release_date                                       song_name  \
# 0          2024-07-19                                             Who
# 1          2024-05-17                              BIRDS OF A FEATHER
# 2          2024-04-12                                        Espresso
# 3          2024-06-06                            Please Please Please
# 4          2024-05-04                                     Not Like Us
# 5          2024-02-02                                       Gata Only
# 6          2024-04-05                                Good Luck, Babe!
# 7          2024-06-21                    Si Antes Te Hubiera Conocido
# 8          2024-04-05                                Beautiful Things
# 9          2024-05-31                              A Bar Song (Tipsy)
# 10         2024-04-26                             MILLION DOLLAR BABY
# 11         2024-06-28             Alibi (with Pabllo Vittar & Yseult)
# 12         2024-03-22                                       Too Sweet
# 13         2024-05-10           I Had Some Help (Feat. Morgan Wallen)
# 14         2023-09-15                                    Lose Control
# 15         2024-07-12                                         Houdini
# 16         2024-05-10                                      Stargazing
# 17         2022-09-16                                End of Beginning
# 18         2022-05-20                                       As It Was
# 19         2024-05-23                               REAL GANGSTA LOVE
# 20         2024-07-11                      i like the way you kiss me
# 21         2019-08-23                                    Cruel Summer
# 22         2024-03-08        we can't be friends (wait for your love)
# 23         2023-06-23  One Of The Girls (with JENNIE, Lily Rose Depp)
# 24         2015-04-06                                The Night We Met
# 25         2024-05-17                                           LUNCH
# 26         2024-02-16                     Austin (Boots Stop Workin')
# 27         2024-06-07                                            Move
# 28         2024-02-16                                 Belong Together
# 29         2024-06-27                                        Rockstar
# 30         2008-05-26                                    Viva La Vida
# 31         2023-12-01                                            LUNA
# 32         2024-04-18                   Fortnight (feat. Post Malone)
# 33         2013-04-19                                 Sweater Weather
# 34         2013-09-09                                I Wanna Be Yours
# 35         2024-07-19                                    Chk Chk Boom
# 36         2024-05-17                                         CHIHIRO
# 37         2024-04-17                                          Mirame
# 38         2024-04-03                                           Santa
# 39         2024-05-23                      BAND4BAND (feat. Lil Baby)
# 40         2024-06-28                      Mamushi (feat. Yuki Chiba)
# 41         2023-09-22                                      HOT TO GO!
# 42         2024-04-05                                    Slow It Down
# 43         2024-07-19      Smeraldo Garden Marching Band (feat. Loco)
# 44         2024-04-05                              I Don't Wanna Wait
# 45         2023-07-28                      FE!N (feat. Playboi Carti)
# 46         2024-07-11                 Did It First (with Central Cee)
# 47         2023-11-03             Seven (feat. Latto) (Explicit Ver.)
# 48         2022-10-14                                    Stick Season
# 49         2024-07-03                                           Tough
#
#     song_popularity_rating                           artist_name  \
# 0                       92                               [Jimin]
# 1                       99                       [Billie Eilish]
# 2                       99                   [Sabrina Carpenter]
# 3                       98                   [Sabrina Carpenter]
# 4                       97                      [Kendrick Lamar]
# 5                       96                 [FloyyMenor, Cris Mj]
# 6                       96                       [Chappell Roan]
# 7                       94                             [KAROL G]
# 8                       91                        [Benson Boone]
# 9                       88                           [Shaboozey]
# 10                      95                       [Tommy Richman]
# 11                      90    [Sevdaliza, Pabllo Vittar, Yseult]
# 12                      89                              [Hozier]
# 13                      95          [Post Malone, Morgan Wallen]
# 14                      91                         [Teddy Swims]
# 15                      84                              [Eminem]
# 16                      93                         [Myles Smith]
# 17                      93                                 [Djo]
# 18                      92                        [Harry Styles]
# 19                      92                              [Trueno]
# 20                      76                             [Artemas]
# 21                      92                        [Taylor Swift]
# 22                      90                       [Ariana Grande]
# 23                      91  [The Weeknd, JENNIE, Lily-Rose Depp]
# 24                      89                          [Lord Huron]
# 25                      94                       [Billie Eilish]
# 26                      91                               [Dasha]
# 27                      89        [Adam Port, Stryv, Keinemusik]
# 28                      91                          [Mark Ambor]
# 29                      93                                [LISA]
# 30                      88                            [Coldplay]
# 31                      91                                [Feid]
# 32                      91                        [Taylor Swift]
# 33                      90                   [The Neighbourhood]
# 34                      91                      [Arctic Monkeys]
# 35                      65                          [Stray Kids]
# 36                      92                       [Billie Eilish]
# 37                      88            [Blessd, Ovy On The Drums]
# 38                      84                             [Rvssian]
# 39                      91               [Central Cee, Lil Baby]
# 40                      86                 [Megan Thee Stallion]
# 41                      90                       [Chappell Roan]
# 42                      89                        [Benson Boone]
# 43                      79                               [Jimin]
# 44                      90           [David Guetta, OneRepublic]
# 45                      90                        [Travis Scott]
# 46                      85              [Ice Spice, Central Cee]
# 47                      86                           [Jung Kook]
# 48                      90                          [Noah Kahan]
# 49                      88                 [Quavo, Lana Del Rey]
#
#     album_total_tracks                                         album_link  \
# 0                    7  https://open.spotify.com/album/15XcLhiVMlSOipU...
# 1                   10  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 2                    1  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 3                    2  https://open.spotify.com/album/5bBaoign62r1i7O...
# 4                    1  https://open.spotify.com/album/5JjnoGJyOxfSZUZ...
# 5                    1  https://open.spotify.com/album/5tSQtQGkrCJx3ho...
# 6                    1  https://open.spotify.com/album/1WAjjRMfZjEXtB0...
# 7                    1  https://open.spotify.com/album/5ylbxH7EqpsmHZC...
# 8                   15  https://open.spotify.com/album/168CdR21lfn0TTy...
# 9                   12  https://open.spotify.com/album/0DLvFVIfwt3OHdK...
# 10                   2  https://open.spotify.com/album/2Z1gnUf3nbn6Dtw...
# 11                   1  https://open.spotify.com/album/2m0euKZUDcoyEXH...
# 12                  20  https://open.spotify.com/album/3P4SQqMMgjqfqVx...
# 13                   1  https://open.spotify.com/album/1woYXxyyxTQJ0E0...
# 14                  10  https://open.spotify.com/album/7nacKlk586eLRBS...
# 15                  19  https://open.spotify.com/album/3kjHLu1pL7tdY88...
# 16                   1  https://open.spotify.com/album/3VNxRarx9HUI5w7...
# 17                  13  https://open.spotify.com/album/4JDXBZdRPId4dev...
# 18                  13  https://open.spotify.com/album/5r36AJ6VOJtp00o...
# 19                  13  https://open.spotify.com/album/3EWJoKrG9XnCjvA...
# 20                  14  https://open.spotify.com/album/5nzSCZ7NhKvAysI...
# 21                  18  https://open.spotify.com/album/1NAmidJlEaVgA3M...
# 22                  13  https://open.spotify.com/album/5EYKrEDnKhhcNxG...
# 23                   3  https://open.spotify.com/album/7tzVd1fwkxsoryt...
# 24                  14  https://open.spotify.com/album/4sD1qg4jwTZR4mv...
# 25                  10  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 26                   8  https://open.spotify.com/album/40HsqPqeSR9Xe3I...
# 27                   1  https://open.spotify.com/album/4M8ThNHbNjda2cP...
# 28                   1  https://open.spotify.com/album/3PlCMwyq6nuQYto...
# 29                   5  https://open.spotify.com/album/7wIIhHPyaxAHRvd...
# 30                  10  https://open.spotify.com/album/1CEODgTmTwLyabv...
# 31                  10  https://open.spotify.com/album/0lgs2Sa82lyX89n...
# 32                  16  https://open.spotify.com/album/1Mo4aZ8pdj6L1jx...
# 33                  11  https://open.spotify.com/album/4xkM0BwLM9H2IUc...
# 34                  12  https://open.spotify.com/album/78bpIziExqiI9qz...
# 35                   8  https://open.spotify.com/album/1uLAcaywb5673rQ...
# 36                  10  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 37                   1  https://open.spotify.com/album/5oCAS6VzHoESewt...
# 38                   2  https://open.spotify.com/album/3uzutRS5qX4ng5S...
# 39                   1  https://open.spotify.com/album/4AzPr5SUpNF553e...
# 40                  18  https://open.spotify.com/album/0FzWvaeMBfKBCqx...
# 41                  14  https://open.spotify.com/album/0EiI8ylL0FmWWpg...
# 42                  15  https://open.spotify.com/album/168CdR21lfn0TTy...
# 43                   7  https://open.spotify.com/album/15XcLhiVMlSOipU...
# 44                   2  https://open.spotify.com/album/0wCLHkBRKcndhMQ...
# 45                  19  https://open.spotify.com/album/18NOKLkZETa4sWw...
# 46                   1  https://open.spotify.com/album/1SiWjniEb94wSFZ...
# 47                  11  https://open.spotify.com/album/5pSk3c3wVwnb2ar...
# 48                  14  https://open.spotify.com/album/50ZenUP4O2Q5eCy...
# 49                   1  https://open.spotify.com/album/58XIBpQOAw7E2qC...
#
#                                             song_link
# 0   https://open.spotify.com/track/7tI8dRuH2Yc6Ruo...
# 1   https://open.spotify.com/track/6dOtVTDdiauQNBQ...
# 2   https://open.spotify.com/track/2qSkIjg1o9h3YT9...
# 3   https://open.spotify.com/track/5N3hjp1WNayUPZr...
# 4   https://open.spotify.com/track/6AI3ezQ4o3HUoP6...
# 5   https://open.spotify.com/track/6XjDF6nds4DE2BB...
# 6   https://open.spotify.com/track/0WbMK4wrZ1wFSty...
# 7   https://open.spotify.com/track/6WatFBLVB0x077x...
# 8   https://open.spotify.com/track/3xkHsmpQCBMytMJ...
# 9   https://open.spotify.com/track/5fZJQrFKWQLb7Fp...
# 10  https://open.spotify.com/track/5AJ9hqTS2wcFQCE...
# 11  https://open.spotify.com/track/5496lks6V3fh1mZ...
# 12  https://open.spotify.com/track/5Z0UnEtpLDQyYlW...
# 13  https://open.spotify.com/track/7221xIgOnuakPdL...
# 14  https://open.spotify.com/track/17phhZDn6oGtzMe...
# 15  https://open.spotify.com/track/1CDQzbCz4KSQxHe...
# 16  https://open.spotify.com/track/3Vr3zh0r7ALn8VL...
# 17  https://open.spotify.com/track/3qhlB30KknSejmI...
# 18  https://open.spotify.com/track/4Dvkj6JhhA12EX0...
# 19  https://open.spotify.com/track/1pymWRCuZfCd0zd...
# 20  https://open.spotify.com/track/3JG1uFc40wfyrqa...
# 21  https://open.spotify.com/track/1BxfuPKGuaTgP7a...
# 22  https://open.spotify.com/track/51ZQ1vr10ffzbwI...
# 23  https://open.spotify.com/track/7CyPwkp0oE8Ro9D...
# 24  https://open.spotify.com/track/3hRV0jL3vUpRrcy...
# 25  https://open.spotify.com/track/629DixmZGHc7ILt...
# 26  https://open.spotify.com/track/2uqYupMHANxnwge...
# 27  https://open.spotify.com/track/1BJJbSX6muJVF2A...
# 28  https://open.spotify.com/track/5uQ7de4EWjb3rkc...
# 29  https://open.spotify.com/track/6vvPecFTmWxDfEJ...
# 30  https://open.spotify.com/track/1mea3bSkSGXuIRv...
# 31  https://open.spotify.com/track/7bywjHOc0wSjGGb...
# 32  https://open.spotify.com/track/2OzhQlSqBEmt7hm...
# 33  https://open.spotify.com/track/2QjOHCTQ1Jl3zaw...
# 34  https://open.spotify.com/track/5XeFesFbtLpXzIV...
# 35  https://open.spotify.com/track/0GqAWZe1A5ecKad...
# 36  https://open.spotify.com/track/7BRD7x5pt8Lqa1e...
# 37  https://open.spotify.com/track/2btNsI4OvcVl7SA...
# 38  https://open.spotify.com/track/6a9Z1jUms915w4O...
# 39  https://open.spotify.com/track/7iabz12vAuVQYye...
# 40  https://open.spotify.com/track/5b3XJ1pjrHO5JtY...
# 41  https://open.spotify.com/track/4xdBrk0nFZaP54v...
# 42  https://open.spotify.com/track/51eSHglvG1RJXtL...
# 43  https://open.spotify.com/track/1agDCV4zQqaFwJQ...
# 44  https://open.spotify.com/track/331l3xABO0HMr1K...
# 45  https://open.spotify.com/track/42VsgItocQwOQC3...
# 46  https://open.spotify.com/track/57lsYy0OZLNb5OQ...
# 47  https://open.spotify.com/track/2HRgqmZQC0MC7Ge...
# 48  https://open.spotify.com/track/0mflMxspEfB0VbI...
# 49  https://open.spotify.com/track/22DH8NChecsgPxD...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   album_id                50 non-null     object
#  1   album_name              50 non-null     object
#  2   album_release_date      50 non-null     object
#  3   song_name               50 non-null     object
#  4   song_popularity_rating  50 non-null     int64
#  5   artist_name             50 non-null     object
#  6   album_total_tracks      50 non-null     int64
#  7   album_link              50 non-null     object
#  8   song_link               50 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 3.6+ KB

# %%
df = df.drop_duplicates(subset = ['album_id'])

# %%
df.loc[:, 'album_release_date'] = pd.to_datetime(df['album_release_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   album_id                46 non-null     object
#  1   album_name              46 non-null     object
#  2   album_release_date      46 non-null     datetime64[ns]
#  3   song_name               46 non-null     object
#  4   song_popularity_rating  46 non-null     int64
#  5   artist_name             46 non-null     object
#  6   album_total_tracks      46 non-null     int64
#  7   album_link              46 non-null     object
#  8   song_link               46 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 3.6+ KB
